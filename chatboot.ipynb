# %%
import requests
import json

class telegram_bot():
    def __init__(self):
        self.token = "966733722:AAE4O8m1uPy28J7_g9bmlQoxh68H0KOiqIU"    #write your token here!  
    
        self.url = f"https://api.telegram.org/bot{self.token}"

    def get_updates(self,offset=None):
        url = self.url+"/getUpdates?timeout=100"
        if offset:
            url = url+f"&offset={offset+1}"
        url_info = requests.get(url)
        return json.loads(url_info.content)

    def send_message(self,msg,chat_id):
        url = self.url + f"/sendMessage?chat_id={chat_id}&text={msg}"
        if msg is not None:
            requests.get(url)

    def grab_token(self):
        return tokens

# %%
help(offset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a207ab1c845f> in <module>()
# ----> 1 help(offset)
#
# NameError: name 'offset' is not defined

# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC  #importing machine learning classification algorithm
import random
import pickle

# %%
import nltk
import numpy as np
import string
import warnings
import re   #Library for regex
import heapq  
import numpy as np
nltk.download("punkt")
nltk.download("wordnet")
warnings.filterwarnings("ignore")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
responses = {0 : {"intent":"greetings","response":['Hi ','How can I help you','Hello']}, 
1 : {"intent":"about gnits","response":['G.Narayanamma Institute of Technology and Science, a leading Engineering college in Hyderabad for women, was founded by late Sri G.Pulla Reddy garu in 1997, with an objective of providing excellent learning facilities for women to pursue education in Engineering since two decades. GNITS received UGC autonomous status for 10 years from 2018 and is affiliated to Jawaharlal Nehru Technological University (JNTU-H), Hyderabad. It is approved by All India Council for Technical Education (AICTE), accredited by NAAC & NBA (AICTE) and ISO 9001:2015 Certified Institution. ']},
2:{"intent":"branches/departments","response":['Computer Science Engineering(CSE),Electronics and communication Engineering(ECE),Information technology(IT),Electrical and Electronics Engineering(EEE),Electronics and Telematics Engineering(ETM)']},5:{"intent":"fee","response":['Yes there is availability of hostel within campus with all the facilities']},
3:{"intent":"placements","response":['533 offers in top companies and highest of 40 lakhs at adobe']},
4:{"intent":"Thank ","response":['You are welcome,come back again.Here to give you info of our college']},
6:{"intent":"contactno.","response":['Dr.K.Ramesh Reddy , Principal-GNITS \n G. Narayanamma Institute of Technology and Science (for women) \n Shaikpet, Hyderabad - 500104, \n Telangana State, India Phone : +91-(0)-40- 23565648, Fax : +91-(0)-4023564187 \n Email:principal@gnits.ac.in , principalgnits97@gmail.com']}
}

# %%
data=[["Hi Good Morning",0],["Hello madian",0],["heya",0],["Thank you",4],['Thanks',4],['Thank u',4],["About GNITS",1],["GNITS",1],["G Narayanamma institute of Technology",1],["Tell me about GNITS",1],["What are the branches in gnits",2],["Departments in gnits",2],["placements in gnits",3],["highest package in placements",3],["placements",3],["Hostel availability",5],["is hostel vailable",5],["hostel in gnits",5],["college contact no:",6],["contact no of gnits",6],["How to contact gnits",6],["Thank you",7],["Thanks",7]]

# %%
#converting it into pandas dataframe
df = pd.DataFrame(data, columns = ['text', 'intent'])

# %%
df
# Out:
#                                      text  intent
# 0                         Hi Good Morning       0
# 1                            Hello madian       0
# 2                                    heya       0
# 3                               Thank you       4
# 4                                  Thanks       4
# 5                                 Thank u       4
# 6                             About GNITS       1
# 7                                   GNITS       1
# 8   G Narayanamma institute of Technology       1
# 9                     Tell me about GNITS       1
# 10         What are the branches in gnits       2
# 11                   Departments in gnits       2
# 12                    placements in gnits       3
# 13          highest package in placements       3
# 14                             placements       3
# 15                    Hostel availability       5
# 16                     is hostel vailable       5
# 17                        hostel in gnits       5
# ...

# %%
x = df['text']   #seperating x from data
y = df['intent']   # seperating y from data (intents are encoded into numbers as machine can only predict numbers)

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(x)  # X has tfidfed vectors

# %%
clf  = LinearSVC(max_iter=800, C=0.1)

# %%
clf.fit(X,y)
# Out:
# LinearSVC(C=0.1, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=800,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0)

# %%
text_test = ["GNITS"]

# %%
X_test = vectorizer.transform(text_test)

# %%
prediction = clf.predict(X_test)

# %%
print(prediction)
# Out:
# [1]

# %%
pickle.dump(clf,open("model.pkl", 'wb'))

# %%
tbot = telegram_bot()

update_id = None
def response(user_response):
    text_test = [user_response]
    X_test = vectorizer.transform(text_test)
    load_model = pickle.load(open("model.pkl", 'rb')) #loading
    prediction = load_model.predict(X_test)
    #if prediction[0]!=null:
    reply = random.choice(responses[prediction[0]]["response"])
    return reply
      
    #else:
      #return "I am sorry.I am not able to get you"
      




while True:
    print("...")
    updates = tbot.get_updates(offset=update_id)
    updates = updates['result']
    print(updates)
    if updates:
        for item in updates:
            update_id = item["update_id"]
            print(update_id)
            try:
                message = item["message"]["text"]
                print(message)
            except:
                message = None
            from_ = item["message"]["from"]["id"]
            print(from_)

            reply = response(message)
            tbot.send_message(reply,from_)
# Out:
# ...
# [{'update_id': 55181469, 'message': {'message_id': 1, 'from': {'id': 881251976, 'is_bot': False, 'first_name': 'Preethika', 'last_name': 'Rao'}, 'chat': {'id': 881251976, 'first_name': 'Preethika', 'last_name': 'Rao', 'type': 'private'}, 'date': 1594576783, 'text': '/start', 'entities': [{'offset': 0, 'length': 6, 'type': 'bot_command'}]}}]
# 55181469
# /start
# 881251976
# ...
# [{'update_id': 55181470, 'message': {'message_id': 3, 'from': {'id': 881251976, 'is_bot': False, 'first_name': 'Preethika', 'last_name': 'Rao', 'language_code': 'en'}, 'chat': {'id': 881251976, 'first_name': 'Preethika', 'last_name': 'Rao', 'type': 'private'}, 'date': 1594576795, 'text': '/start', 'entities': [{'offset': 0, 'length': 6, 'type': 'bot_command'}]}}]
# 55181470
# /start
# 881251976
# ...
# ...
